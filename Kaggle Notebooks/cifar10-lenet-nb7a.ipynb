# %%
#Motivation: https://github.com/rslim087a/PyTorch-for-Deep-Learning-and-Computer-Vision-Course-All-Codes-
import torch
import numpy as np
from torch import nn
from time import time
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# %%
# Detect if a GPU is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %%
transform = transforms.Compose([transforms.Resize((32,32)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, ), (0.5, ))
                               ])
training_dataset = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
validation_dataset = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)

training_loader = torch.utils.data.DataLoader(dataset=training_dataset, batch_size=100, shuffle=True)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=100, shuffle=False)
# Out:
# 100.0%

# %%
def im_convert(tensor):
    image = tensor.clone().detach().numpy()
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
    image = image.clip(0, 1)
    return image

# %%
classes = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
dataiter = iter(training_loader)
images, labels = next(dataiter)
fig = plt.figure(figsize=(25, 6))

for idx in range(20):
    ax = fig.add_subplot(2, 10, idx + 1)
    plt.imshow(im_convert(images[idx]))
    ax.set_title(classes[labels[idx].item()])

# %%
class LeNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 24, 5, 1)
        self.conv2 = nn.Conv2d(24, 48, 5, 1)
        # How do we get (5*5*48)? - (32 - 5 + 1), (28/2), (14 - 5 + 1), (10/2)
        self.fc1 = nn.Linear(5*5*48, 512)
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)
        
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 5*5*48)
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = self.fc2(x)
        return x

# %%
model = LeNet().to(device)
model
# Out:
# LeNet(
#   (conv1): Conv2d(3, 24, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(24, 48, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=1200, out_features=512, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 650714

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
# %%time

epochs = 15
running_loss_history = []
running_correct_history = []
val_running_loss_history = []
val_running_correct_history = []

for epoch in range(epochs):
    
    running_loss = 0.0
    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0
    start_time = time()

    for inputs, labels in training_loader:
        outputs = model(inputs.to(device))
        loss = criterion(outputs, labels.to(device))
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        _, preds = torch.max(outputs, 1)
        preds = preds.detach()
        preds = preds.cpu()
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)
    else:
        with torch.no_grad():
            for val_inputs, val_labels in validation_loader:
                val_outputs = model(val_inputs.to(device))
                val_loss = criterion(val_outputs, val_labels.to(device))
                
                _, val_preds = torch.max(val_outputs, 1)
                val_preds = val_preds.detach()
                val_preds = val_preds.cpu()
                val_running_loss += val_loss.item()
                val_running_corrects += torch.sum(val_preds == val_labels.data)
        
        epoch_loss = running_loss / len(training_loader)
        epoch_acc = running_corrects.float() / len(training_loader)
        val_epoch_loss = val_running_loss / len(validation_loader)
        val_epoch_acc = val_running_corrects.float() / len(validation_loader)

        running_loss_history.append(epoch_loss)
        running_correct_history.append(epoch_acc)
        val_running_loss_history.append(val_epoch_loss)
        val_running_correct_history.append(val_epoch_acc)
        end_time = time()
    
        print("epoch: ", epoch + 1)
        print("time: {:.2f} seconds".format(end_time - start_time))
        print("training loss: {:.4f}, training accuracy: {:.4f}".format(epoch_loss, epoch_acc.item()))
        print("validation loss: {:.4f}, validation accuracy: {:.4f}".format(val_epoch_loss, val_epoch_acc.item()))
# Out:
# epoch:  1
# time: 36.61 seconds
# training loss: 1.8538, training accuracy: 32.7200
# validation loss: 1.6313, validation accuracy: 41.0100
# epoch:  2
# time: 40.17 seconds
# training loss: 1.5546, training accuracy: 43.8800
# validation loss: 1.4900, validation accuracy: 46.4400
# epoch:  3
# time: 37.54 seconds
# training loss: 1.4484, training accuracy: 48.0560
# validation loss: 1.4034, validation accuracy: 50.2500
# epoch:  4
# time: 36.65 seconds
# training loss: 1.3697, training accuracy: 51.0320
# validation loss: 1.3564, validation accuracy: 51.2800
# epoch:  5
# time: 36.23 seconds
# training loss: 1.3102, training accuracy: 53.3900
# validation loss: 1.2970, validation accuracy: 53.6900
# epoch:  6
# time: 39.90 seconds
# training loss: 1.2582, training accuracy: 55.2100
# validation loss: 1.2561, validation accuracy: 55.4800
# epoch:  7
# time: 34.94 seconds
# training loss: 1.2110, training accuracy: 57.1000
# validation loss: 1.2073, validation accuracy: 57.0700
# epoch:  8
# time: 35.23 seconds
# training loss: 1.1721, training accuracy: 58.5720
# validation loss: 1.1912, validation accuracy: 57.4700
# epoch:  9
# time: 35.56 seconds
# training loss: 1.1373, training accuracy: 59.8960
# validation loss: 1.1614, validation accuracy: 58.8300
# epoch:  10
# time: 34.67 seconds
# training loss: 1.1044, training accuracy: 61.1400
# validation loss: 1.1443, validation accuracy: 59.0200
# epoch:  11
# time: 35.89 seconds
# training loss: 1.0789, training accuracy: 61.9220
# validation loss: 1.1206, validation accuracy: 60.2600
# epoch:  12
# time: 34.92 seconds
# training loss: 1.0512, training accuracy: 63.1880
# validation loss: 1.0993, validation accuracy: 61.6500
# epoch:  13
# time: 36.60 seconds
# training loss: 1.0265, training accuracy: 63.9540
# validation loss: 1.0959, validation accuracy: 61.3900
# epoch:  14
# time: 48.44 seconds
# training loss: 1.0024, training accuracy: 64.8760
# validation loss: 1.0719, validation accuracy: 62.5200
# epoch:  15
# time: 43.31 seconds
# training loss: 0.9796, training accuracy: 65.7420
# validation loss: 1.0681, validation accuracy: 62.7100
# CPU times: total: 22min 19s
# Wall time: 9min 26s

# %%
plt.plot(running_loss_history, label='Training loss')
plt.plot(val_running_loss_history, label='Validation loss')
plt.legend()

# %%
plt.plot(running_correct_history, label='Training accuracy')
plt.plot(val_running_correct_history, label='Validation accuracy')
plt.legend()

# %%
import requests, io
from PIL import Image

headers = {'User-Agent' : 'Mozilla/5.0 ...' }
url = 'http://www.edgeofexistence.org/wp-content/uploads/2017/06/Anilany-helenae_KMullin-1000x697.jpg'
response = requests.get(url, stream = True, headers = headers)
#img = Image.open(response.raw)
img = Image.open(io.BytesIO(response.content))
print(img.size)
plt.imshow(img)
# Out:
# (1000, 697)

# %%
import PIL.ImageOps
img = transform(img) 
plt.imshow(im_convert(img))

# %%
print(img.shape)
img = img.unsqueeze(0)
print(img.shape)
output = model(img.to(device))
_, pred = torch.max(output, 1)
print(classes[pred.item()])
# Out:
# torch.Size([3, 32, 32])
# torch.Size([1, 3, 32, 32])
# cat

# %%
dataiter = iter(validation_loader)
images_, labels = next(dataiter)
output = model(images_.to(device))
_, preds = torch.max(output, 1)

fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):
  ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
  plt.imshow(im_convert(images_[idx]))
  ax.set_title("{} ({})".format(str(classes[preds[idx].item()]), str(classes[labels[idx].item()])), color=("green" if preds[idx]==labels[idx] else "red"))
